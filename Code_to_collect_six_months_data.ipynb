# %%
import pandas as pd

# %%
Apr_2022=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\Secondary\Apr_2022.csv',encoding = 'unicode_escape')
Dec_2021=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\Secondary\Dec-2021.csv',encoding = 'unicode_escape')
Feb_2022=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\secondary\Feb_2022.csv',encoding = 'unicode_escape')
Jan_2022=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\secondary\Jan_2022.csv',encoding = 'unicode_escape')
March_2022=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\secondary\March_2022.csv',encoding = 'unicode_escape')
Nov_2021=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\secondary\Nov_2021.csv',encoding = 'unicode_escape')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (12,13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
Apr_2022
# Out:
#        REGION          STATE  OUTLET ID           OUTLET NAME       DATE  \
# 0        GT-4            NER    7032923           A.C.T store  01-Apr-22
# 1        GT-4    WEST BENGAL     372276  sipahi shaw and sons  01-Apr-22
# 2        GT-4    WEST BENGAL     372276  sipahi shaw and sons  01-Apr-22
# 3        GT-3  CENTRAL -UP-2     607748          Vinit Kirana  01-Apr-22
# 4        GT-3  CENTRAL -UP-2     607748          Vinit Kirana  01-Apr-22
# ...       ...            ...        ...                   ...        ...
# 830496   GT-2          BIHAR     569805     satish  ji kirana  30-Apr-22
# 830497   GT-2          BIHAR     569805     satish  ji kirana  30-Apr-22
# 830498   GT-2          BIHAR     569805     satish  ji kirana  30-Apr-22
# 830499   GT-2          BIHAR     569805     satish  ji kirana  30-Apr-22
# 830500   GT-2          BIHAR     569805     satish  ji kirana  30-Apr-22
#
#          Invoice_ID           Bill_No   SKU CODE          SKU CODE.1  \
# ...

# %%
df_list=[Nov_2021,Dec_2021,Jan_2022,Feb_2022,March_2022,Apr_2022]
df_list=[df.groupby(['REGION','STATE'])['Amount'].sum() for df in df_list]
data1=pd.DataFrame(df_list).T

# %%
six_Amount=pd.DataFrame()
six_Amount['Nov_2021']=data1.iloc[:,0:1]
six_Amount['Dec_2021']=data1.iloc[:,1:2]
six_Amount['Jan_2022']=data1.iloc[:,2:3]
six_Amount['Feb_2022']=data1.iloc[:,3:4]
six_Amount['March_2022']=data1.iloc[:,4:5]
six_Amount['Apr_2022']=data1.iloc[:,5:6]

# %%
six_Amount
# Out:
#                             Nov_2021     Dec_2021     Jan_2022     Feb_2022  \
# REGION STATE
# GT-1   CHANDIGARH        13436424.16  12147571.67   8161110.55  10394036.15
#        HARYANA           41529929.47  43913667.33  35799890.71  37148618.90
#        HIMACHAL PRADESH  17463588.52  19399218.34  17429812.68  16810186.09
#        JAMMU & KASHMIR   16802788.17  16958170.00  12779889.67  14920748.75
#        PUNJAB            46010259.75  42360893.56  37798708.47  39066908.93
# GT-2   BIHAR             38306251.83  38107726.31  25107519.29  35823265.55
#        DELHI             31144268.11  30666728.74  29007459.42  33128981.46
#        JHARKHAND         18564881.52  17488497.87  15089114.58  19229821.68
#        RAJASTHAN-1       11537744.60  11283599.32   9936277.44  12445868.36
#        RAJASTHAN-2        4278154.09   5463247.71   2904608.62   4631151.50
# GT-3   CENTRAL -UP-1     15449975.13  15296606.50  13174475.35  15800328.59
# ...
