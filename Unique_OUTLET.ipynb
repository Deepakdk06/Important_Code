# %%
import pandas as pd
import numpy as np

# %%
Apr_2022=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\Secondary\Apr_2022.csv',encoding = 'unicode_escape')
Dec_2021=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\Secondary\Dec-2021.csv',encoding = 'unicode_escape')
Feb_2022=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\secondary\Feb_2022.csv',encoding = 'unicode_escape')
Jan_2022=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\secondary\Jan_2022.csv',encoding = 'unicode_escape')
March_2022=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\secondary\March_2022.csv',encoding = 'unicode_escape')
Nov_2021=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\secondary\Nov_2021.csv',encoding = 'unicode_escape')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (12,13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
Apr_2022=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\Secondary\Apr_2022.csv',encoding = 'unicode_escape')
Nov_2021=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\secondary\Nov_2021.csv',encoding = 'unicode_escape')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
Nov_2021,Dec_2021,March_2022,Apr_2022
# Out:
#        REGION          STATE  OUTLET ID            OUTLET NAME   DATE  \
# 0        GT-2    RAJASTHAN-2     376118            Malik Store  44501
# 1        GT-2    RAJASTHAN-2     376118            Malik Store  44501
# 2        GT-2    RAJASTHAN-2     376118            Malik Store  44501
# 3        GT-2    RAJASTHAN-2     638329          ramdev kirana  44501
# 4        GT-2    RAJASTHAN-2     638329          ramdev kirana  44501
# ...       ...            ...        ...                    ...    ...
# 779890   GT-2          DELHI      95098              n.k store  44530
# 779891   GT-2          DELHI      95098              n.k store  44530
# 779892   GT-2          DELHI      95098              n.k store  44530
# 779893   GT-3  CENTRAL -UP-1     168335        Ghansyam kirana  44530
# 779894   GT-3  CENTRAL -UP-2     492936  Banavari kerana store  44530
#
#          Invoice_ID           Bill_No   SKU CODE         SKU CODE.1  \
# ...

# %% [markdown]
# # One_Month_Unique_Outlet

# %%
Nov_2021=Nov_2021.groupby(['REGION','STATE'])['OUTLET ID'].nunique()

# %%
pd.DataFrame(Nov_2021)
# Out:
#                          OUTLET ID
# REGION STATE
# GT-1   CHANDIGARH              510
#        HARYANA                6334
#        HIMACHAL PRADESH       1958
#        JAMMU & KASHMIR        2206
#        PUNJAB                 6735
# GT-2   BIHAR                  9183
#        DELHI                 10768
#        JHARKHAND              6702
#        RAJASTHAN-1            4608
#        RAJASTHAN-2            1730
# GT-3   CENTRAL -UP-1          6913
#        CENTRAL -UP-2          3925
#        EASTERN UP            10240
#        UTTRAKHAND             6501
#        WEST-UP-1             10336
#        WEST-UP-2              4641
#        WEST-UP-3              4108
# GT-4   NER                    6616
#        ORISSA                 2048
#        WEST BENGAL            9239
# GT-5   CHHATTISGARH            638
#        MADHYA PRADESH-1       3610
#        MADHYA PRADESH-2       1024
# GT-6   GOA                    1130
#        GUJARAT                2205
# ...

# %%
Nov_2021.to_csv('Nov_2021_unique_outlet.csv')

# %% [markdown]
# # 6_Months_Unique_Outlet

# %%
df_list=[Nov_2021,Dec_2021,Jan_2022,Feb_2022,March_2022,Apr_2022]
df_list=[df.iloc[:,0:3].groupby(['REGION','STATE'])['OUTLET ID'].nunique() for df in df_list]

# %%
df_list
# Out:
# [REGION  STATE
#  GT-1    CHANDIGARH            510
#          HARYANA              6334
#          HIMACHAL PRADESH     1958
#          JAMMU & KASHMIR      2206
#          PUNJAB               6735
#  GT-2    BIHAR                9183
#          DELHI               10768
#          JHARKHAND            6702
#          RAJASTHAN-1          4608
#          RAJASTHAN-2          1730
#  GT-3    CENTRAL -UP-1        6913
#          CENTRAL -UP-2        3925
#          EASTERN UP          10240
#          UTTRAKHAND           6501
#          WEST-UP-1           10336
#          WEST-UP-2            4641
#          WEST-UP-3            4108
#  GT-4    NER                  6616
#          ORISSA               2048
#          WEST BENGAL          9239
#  GT-5    CHHATTISGARH          638
#          MADHYA PRADESH-1     3610
#          MADHYA PRADESH-2     1024
#  GT-6    GOA                  1130
#          GUJARAT              2205
#          MUMBAI               2140
# ...

# %%
data1=pd.DataFrame(df_list).T
data1
# Out:
#                          OUTLET ID  OUTLET ID  OUTLET ID  OUTLET ID  \
# REGION STATE
# GT-1   CHANDIGARH              510        518        500        522
#        HARYANA                6334       6973       7244       7492
#        HIMACHAL PRADESH       1958       2418       2226       2260
#        JAMMU & KASHMIR        2206       2399       2022       2312
#        PUNJAB                 6735       7444       7760       8010
# GT-2   BIHAR                  9183       9825      10058      10474
#        DELHI                 10768      11940      12084      12215
#        JHARKHAND              6702       7228       7135       7261
#        RAJASTHAN-1            4608       5292       5377       5462
#        RAJASTHAN-2            1730       2073       2119       2084
# GT-3   CENTRAL -UP-1          6913       6595       7470       7205
#        CENTRAL -UP-2          3925       4286       4353       4404
#        EASTERN UP            10240      10869      11232      11983
# ...

# %%
Unique_Outlet=pd.DataFrame()

# %%
Unique_Outlet['Nov_2021']=data1['OUTLET ID'].iloc[:,0:1]
Unique_Outlet['Dec_2021']=data1['OUTLET ID'].iloc[:,1:2]
Unique_Outlet['Jan_2022']=data1['OUTLET ID'].iloc[:,2:3]
Unique_Outlet['Feb_2022']=data1['OUTLET ID'].iloc[:,3:4]
Unique_Outlet['March_2022']=data1['OUTLET ID'].iloc[:,4:5]
Unique_Outlet['Apr_2022']=data1['OUTLET ID'].iloc[:,5:6]

# %%
Unique_Outlet
# Out:
#                          Nov_2021  Dec_2021  Jan_2022  Feb_2022  March_2022  \
# REGION STATE
# GT-1   CHANDIGARH             510       518       500       522         534
#        HARYANA               6334      6973      7244      7492        7575
#        HIMACHAL PRADESH      1958      2418      2226      2260        2290
#        JAMMU & KASHMIR       2206      2399      2022      2312        2388
#        PUNJAB                6735      7444      7760      8010        8307
# GT-2   BIHAR                 9183      9825     10058     10474       10438
#        DELHI                10768     11940     12084     12215       12490
#        JHARKHAND             6702      7228      7135      7261        7373
#        RAJASTHAN-1           4608      5292      5377      5462        5557
#        RAJASTHAN-2           1730      2073      2119      2084        1652
# GT-3   CENTRAL -UP-1         6913      6595      7470      7205        7094
# ...

# %%
# All Code for 6 months unique outlet count

df_list=[Nov_2021,Dec_2021,Jan_2022,Feb_2022,March_2022,Apr_2022]
df_list=[df.iloc[:,0:3].groupby(['REGION','STATE'])['OUTLET ID'].nunique() for df in df_list]
data1=pd.DataFrame(df_list).T
Unique_Outlet1=pd.DataFrame()
Unique_Outlet1['Nov_2021']=data1['OUTLET ID'].iloc[:,0:1]
Unique_Outlet1['Dec_2021']=data1['OUTLET ID'].iloc[:,1:2]
Unique_Outlet1['Jan_2022']=data1['OUTLET ID'].iloc[:,2:3]
Unique_Outlet1['Feb_2022']=data1['OUTLET ID'].iloc[:,3:4]
Unique_Outlet1['March_2022']=data1['OUTLET ID'].iloc[:,4:5]
Unique_Outlet1['Apr_2022']=data1['OUTLET ID'].iloc[:,5:6]

# %%
Unique_Outlet1
# Out:
#                          Nov_2021  Dec_2021  Jan_2022  Feb_2022  March_2022  \
# REGION STATE
# GT-1   CHANDIGARH             510       518       500       522         534
#        HARYANA               6334      6973      7244      7492        7575
#        HIMACHAL PRADESH      1958      2418      2226      2260        2290
#        JAMMU & KASHMIR       2206      2399      2022      2312        2388
#        PUNJAB                6735      7444      7760      8010        8307
# GT-2   BIHAR                 9183      9825     10058     10474       10438
#        DELHI                10768     11940     12084     12215       12490
#        JHARKHAND             6702      7228      7135      7261        7373
#        RAJASTHAN-1           4608      5292      5377      5462        5557
#        RAJASTHAN-2           1730      2073      2119      2084        1652
# GT-3   CENTRAL -UP-1         6913      6595      7470      7205        7094
# ...

# %% [markdown]
# # Unique_outlet_Categories_wise

# %% [markdown]
# # One_Month

# %%
April_2022=Apr_2022.groupby(['REGION','STATE','PRODUCT NEW'])['OUTLET ID'].nunique()
unique_outlet=pd.DataFrame(April_2022)
unique_outlet.to_csv('Unique_Outlet_April_2022.csv')
df=pd.read_csv('Unique_Outlet_April_2022.csv')
df_1=df.set_index(['REGION','STATE','PRODUCT NEW'])['OUTLET ID'].unstack()
df_1=df.pivot(index=['REGION','STATE'], columns='PRODUCT NEW', values='OUTLET ID')

# %%
pd.DataFrame(df_1)
# Out:
# PRODUCT NEW                  BL     GGP     GR    Hing     KWL      MM  \
# REGION STATE
# GT-1   CHANDIGARH         310.0   163.0   10.0   240.0    11.0   243.0
#        HARYANA           3379.0  1189.0   30.0  1751.0   225.0  3898.0
#        HIMACHAL PRADESH  1457.0   506.0    NaN   648.0    86.0  1347.0
#        JAMMU & KASHMIR   1276.0   645.0    NaN   222.0   104.0   415.0
#        PUNJAB            3265.0  1567.0   50.0  1932.0   593.0  3636.0
# GT-2   BIHAR             5639.0  1289.0   18.0  2296.0   871.0  5451.0
#        DELHI             2694.0  1141.0   42.0  2338.0   498.0  6458.0
#        JHARKHAND         3507.0  1480.0   51.0  1153.0   672.0  4766.0
#        RAJASTHAN-1       2639.0  1044.0    NaN  1082.0   577.0  3571.0
#        RAJASTHAN-2        368.0   208.0    NaN    68.0   156.0   517.0
# GT-3   CENTRAL -UP-1     2674.0   226.0    NaN   456.0  1801.0  2896.0
#        CENTRAL -UP-2     1979.0   392.0    NaN   460.0  1330.0  1477.0
# ...

# %% [markdown]
# # 6_Months

# %%
# All codes

df_list1=[Dec_2021,Jan_2022,Feb_2022,March_2022,Apr_2022]
df_list1=[df2.groupby(['REGION','STATE'])['OUTLET ID'].nunique() for df2 in df_list]
unique_outlet2=pd.DataFrame(df_list1).T

data=pd.DataFrame()
data['Nov_2021']=a.iloc[:,0:1]
data['Dec_2021']=a.iloc[:,1:2]
data['Jan_2022']=a.iloc[:,2:3]
data['Feb_2022']=a.iloc[:,3:4]
data['March_2022']=a.iloc[:,4:5]
data['Apr_2022']=a.iloc[:,5:6]

data.to_csv('temp3.csv')
df4=pd.read_csv('temp3.csv')
df_1=df4.set_index(['REGION','STATE','PRODUCT NEW'])
df_1=df4.pivot(index=['REGION','STATE'], columns='PRODUCT NEW', values=['Nov_2021','Dec_2021','Jan_2022','Feb_2022','March_2022','Apr_2022'])
df_1.to_csv('6_Months_Categories_wise_unique_Outlet4.csv')

# %%
pd.DataFrame(df_1)
# Out:
#                         Nov_2021                                         \
# PRODUCT NEW                   BL     GGP     GR    Hing     KWL      MM
# REGION STATE
# GT-1   CHANDIGARH          317.0    63.0    NaN   183.0     NaN   197.0
#        HARYANA            2633.0   968.0    NaN  1374.0    70.0  3022.0
#        HIMACHAL PRADESH   1083.0   223.0    NaN   546.0    56.0   635.0
#        JAMMU & KASHMIR    1167.0   261.0    NaN   330.0    60.0   379.0
#        PUNJAB             2589.0  1010.0    NaN  2123.0   416.0  2481.0
# GT-2   BIHAR              4708.0   682.0    NaN  1846.0   696.0  4039.0
#        DELHI              2453.0  1085.0    NaN  2194.0   363.0  5794.0
#        JHARKHAND          2353.0  1123.0    NaN  1218.0   417.0  4849.0
#        RAJASTHAN-1        1906.0   655.0    NaN   562.0   438.0  2219.0
#        RAJASTHAN-2         616.0   146.0    NaN    86.0   183.0   831.0
# GT-3   CENTRAL -UP-1      3139.0   331.0    NaN   928.0  1619.0  2520.0
# ...

# %%
# Seprate rows codes

# %%
df_list1=[Dec_2021,Jan_2022,Feb_2022,March_2022,Apr_2022]

# %%
df_list1=[df2.groupby(['REGION','STATE'])['OUTLET ID'].nunique() for df2 in df_list]
unique_outlet1=pd.DataFrame(df_list1)

# %%
unique_outlet1.T
# Out:
#                          OUTLET ID  OUTLET ID  OUTLET ID  OUTLET ID  OUTLET ID
# REGION STATE
# GT-1   CHANDIGARH              518        500        522        534        505
#        HARYANA                6973       7244       7492       7575       7625
#        HIMACHAL PRADESH       2418       2226       2260       2290       2093
#        JAMMU & KASHMIR        2399       2022       2312       2388       2260
#        PUNJAB                 7444       7760       8010       8307       8265
# GT-2   BIHAR                  9825      10058      10474      10438      10730
#        DELHI                 11940      12084      12215      12490      11573
#        JHARKHAND              7228       7135       7261       7373       7434
#        RAJASTHAN-1            5292       5377       5462       5557       5697
#        RAJASTHAN-2            2073       2119       2084       1652       1149
# GT-3   CENTRAL -UP-1          6595       7470       7205       7094       6918
# ...

# %%
data=pd.DataFrame()

# %%
data['Nov_2021']=a.iloc[:,0:1]
data['Dec_2021']=a.iloc[:,1:2]
data['Jan_2022']=a.iloc[:,2:3]
data['Feb_2022']=a.iloc[:,3:4]
data['March_2022']=a.iloc[:,4:5]
data['Apr_2022']=a.iloc[:,5:6]

# %%
df4
# Out:
#     REGION       STATE PRODUCT NEW  Nov_2021  Dec_2021  Jan_2022  Feb_2022  \
# 0     GT-1  CHANDIGARH          BL     317.0     307.0     311.0     332.0
# 1     GT-1  CHANDIGARH         GGP      63.0      58.0      57.0      73.0
# 2     GT-1  CHANDIGARH          GR       NaN       NaN       NaN      30.0
# 3     GT-1  CHANDIGARH        Hing     183.0     221.0     222.0     266.0
# 4     GT-1  CHANDIGARH         KWL       NaN       NaN       1.0       6.0
# ..     ...         ...         ...       ...       ...       ...       ...
# 349   GT-7   TAMILNADU         PRS       NaN       NaN       NaN       5.0
# 350   GT-7   TAMILNADU          SP     332.0     393.0     376.0     406.0
# 351   GT-7   TAMILNADU          ST      18.0      16.0      36.0      16.0
# 352   GT-7   TAMILNADU         STP     123.0     211.0     224.0     231.0
# 353   GT-7   TAMILNADU           W       8.0       2.0       2.0       2.0
#
#      March_2022  Apr_2022
# 0         388.0     310.0
# ...

# %%
df_1=df4.set_index(['REGION','STATE','PRODUCT NEW'])
df_1=df4.pivot(index=['REGION','STATE'], columns='PRODUCT NEW', values=['Nov_2021','Dec_2021','Jan_2022','Feb_2022','March_2022','Apr_2022'])

# %%
df_1
# Out:
#                         Nov_2021                                         \
# PRODUCT NEW                   BL     GGP     GR    Hing     KWL      MM
# REGION STATE
# GT-1   CHANDIGARH          317.0    63.0    NaN   183.0     NaN   197.0
#        HARYANA            2633.0   968.0    NaN  1374.0    70.0  3022.0
#        HIMACHAL PRADESH   1083.0   223.0    NaN   546.0    56.0   635.0
#        JAMMU & KASHMIR    1167.0   261.0    NaN   330.0    60.0   379.0
#        PUNJAB             2589.0  1010.0    NaN  2123.0   416.0  2481.0
# GT-2   BIHAR              4708.0   682.0    NaN  1846.0   696.0  4039.0
#        DELHI              2453.0  1085.0    NaN  2194.0   363.0  5794.0
#        JHARKHAND          2353.0  1123.0    NaN  1218.0   417.0  4849.0
#        RAJASTHAN-1        1906.0   655.0    NaN   562.0   438.0  2219.0
#        RAJASTHAN-2         616.0   146.0    NaN    86.0   183.0   831.0
# GT-3   CENTRAL -UP-1      3139.0   331.0    NaN   928.0  1619.0  2520.0
# ...

# %%
df_1.to_csv('6_Months_Categories_wise_unique_Outlet1.csv')

# %% [markdown]
# # State_Wise_Multiple_Months Unique_Outlet

# %% [markdown]
# # Two_Months

# %%
# All Code

data_0=pd.concat([Jan_2022,Feb_2022])
Jan_Feb_2022=data_0.drop_duplicates(['OUTLET ID'])
Jan_Feb_2022_Unique_Outlet=Jan_Feb_2022.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
Jan_Feb_2022_Unique_Outlet.to_csv('Jan_Feb_2022_total_Unique_Outlet_count.csv')

# %%
Jan_Feb_2022_Unique_Outlet
# Out:
# REGION  STATE
# GT-1    CHANDIGARH            567
#         HARYANA              8532
#         HIMACHAL PRADESH     2939
#         JAMMU & KASHMIR      2722
#         PUNJAB               9779
# GT-2    BIHAR               11956
#         DELHI               14179
#         JHARKHAND            8113
#         RAJASTHAN-1          6615
#         RAJASTHAN-2          2776
# GT-3    CENTRAL -UP-1        8906
#         CENTRAL -UP-2        5262
#         EASTERN UP          13512
#         UTTRAKHAND           8342
#         WEST-UP-1           11853
#         WEST-UP-2            6205
#         WEST-UP-3            4952
# GT-4    NER                  8172
#         ORISSA               2769
#         WEST BENGAL         13025
# GT-5    CHHATTISGARH         1633
#         MADHYA PRADESH-1     5688
#         MADHYA PRADESH-2     2354
# GT-6    GOA                  1650
#         GUJARAT              3154
#         MUMBAI               3443
#         ROM                  2672
# ...

# %% [markdown]
# # 6_months

# %%
# All Code

data_1=pd.concat([Nov_2021,Dec_2021,Jan_2022,Feb_2022,March_2022,Apr_2022])
All_Months_Unique_Outlet=data_1.drop_duplicates(['OUTLET ID'])
All_Months_Unique_Outlet1=All_Months_Unique_Outlet.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
All_Months_Unique_Outlet1.to_csv('Testing_All_Months_Unique_Outlet_Count.csv')

# %%
data_1=pd.concat([Nov_2021,Dec_2021,Jan_2022,Feb_2022,March_2022,Apr_2022])

# %%
data_1.shape
# Out:
# (5131312, 68)

# %%
All_Months_Unique_Outlet=data_1.drop_duplicates(['OUTLET ID'])

# %%
All_Months_Unique_Outlet
# Out:
#        REGION          STATE  OUTLET ID         OUTLET NAME       DATE  \
# 0        GT-2    RAJASTHAN-2     376118         Malik Store      44501
# 3        GT-2    RAJASTHAN-2     638329       ramdev kirana      44501
# 7        GT-3  CENTRAL -UP-2     638138        Apna E-bazar      44501
# 8        GT-3     EASTERN UP     623372  Sarvesh kir. store      44501
# 12       GT-6        GUJARAT     502645       sai provision      44501
# ...       ...            ...        ...                 ...        ...
# 830427   GT-4    WEST BENGAL     481276       LAHA VARITIES  30-Apr-22
# 830460   GT-4    WEST BENGAL     478168         KOUSHIK ROY  30-Apr-22
# 830466   GT-4    WEST BENGAL     450939       RAJ VARIETIES  30-Apr-22
# 830486   GT-4    WEST BENGAL     379193   MA SHYAMA BHANDER  30-Apr-22
# 830487   GT-3      WEST-UP-2     412750         abdul kalam  30-Apr-22
#
#          Invoice_ID           Bill_No   SKU CODE          SKU CODE.1  \
# ...

# %%
All_Months_Unique_Outlet1=All_Months_Unique_Outlet.groupby(['REGION','STATE'])['OUTLET ID'].nunique()

# %%
All_Months_Unique_Outlet1
# Out:
# REGION  STATE
# GT-1    CHANDIGARH            611
#         HARYANA              9924
#         HIMACHAL PRADESH     3411
#         JAMMU & KASHMIR      3092
#         PUNJAB              11860
# GT-2    BIHAR               13970
#         DELHI               16050
#         JHARKHAND            9002
#         RAJASTHAN-1          7710
#         RAJASTHAN-2          3567
# GT-3    CENTRAL -UP-1       10545
#         CENTRAL -UP-2        6337
#         EASTERN UP          15571
#         UTTRAKHAND           9304
#         WEST-UP-1           13315
#         WEST-UP-2            6761
#         WEST-UP-3            7163
# GT-4    NER                  9288
#         ORISSA               3678
#         WEST BENGAL         17394
# GT-5    CHHATTISGARH         2205
#         MADHYA PRADESH-1     8339
#         MADHYA PRADESH-2     2987
# GT-6    GOA                  2209
#         GUJARAT              4987
#         MUMBAI               4832
#         ROM                  4037
# ...

# %%
All_Months_Unique_Outlet1.to_csv('Testing_All_Months_Unique_Outlet_Count.csv')

# %% [markdown]
# # Categories_Wise_Multiple_Months Unique_Outlet

# %% [markdown]
# # Two_Months

# %%
# All_Codes

dt=pd.concat([Jan_2022,Feb_2022])
dd=dt.groupby(['REGION','STATE','PRODUCT NEW'])['OUTLET ID'].nunique()
dd.to_csv('Jan_feb_2022_Catogories_wise_total_unique_outlet.csv')
dk=pd.read_csv('Jan_feb_2022_Catogories_wise_total_unique_outlet.csv')
df_2=dk.set_index(['REGION','STATE','PRODUCT NEW'])['OUTLET ID'].unstack()
df_2=dk.pivot(index=['REGION','STATE'], columns='PRODUCT NEW', values='OUTLET ID')

# %%
df_2
# Out:
# PRODUCT NEW                  BL     GGP     GR    Hing     KWL      MM  \
# REGION STATE
# GT-1   CHANDIGARH         412.0   101.0   30.0   348.0     7.0   312.0
#        HARYANA           4554.0  1429.0   23.0  2903.0   273.0  5017.0
#        HIMACHAL PRADESH  1980.0   434.0    NaN  1129.0   140.0  1080.0
#        JAMMU & KASHMIR   1690.0   383.0    NaN   502.0   174.0   655.0
#        PUNJAB            4951.0  2085.0    NaN  3391.0   873.0  4932.0
# GT-2   BIHAR             7441.0  1479.0    NaN  3870.0  1059.0  7523.0
#        DELHI             4214.0  2039.0    7.0  4337.0   760.0  9195.0
#        JHARKHAND         4775.0  2378.0    NaN  2176.0  1094.0  6888.0
#        RAJASTHAN-1       3723.0  1179.0    NaN  1901.0   854.0  4274.0
#        RAJASTHAN-2       1301.0   260.0    NaN   360.0   344.0  1443.0
# GT-3   CENTRAL -UP-1     4343.0   622.0    NaN  1326.0  3532.0  4120.0
#        CENTRAL -UP-2     3052.0   499.0    NaN  1529.0  2502.0  2292.0
# ...

# %%
dt=pd.concat([Jan_2022,Feb_2022])

# %%
dd=dt.groupby(['REGION','STATE','PRODUCT NEW'])['OUTLET ID'].nunique()

# %%
dd.to_csv('test-1.csv')

# %%
dk=pd.read_csv('test-1.csv')

# %%
df_2=dk.set_index(['REGION','STATE','PRODUCT NEW'])['OUTLET ID'].unstack()
df_2=dk.pivot(index=['REGION','STATE'], columns='PRODUCT NEW', values='OUTLET ID')

# %%
df_2
# Out:
# PRODUCT NEW                  BL     GGP     GR    Hing     KWL      MM  \
# REGION STATE
# GT-1   CHANDIGARH         412.0   101.0   30.0   348.0     7.0   312.0
#        HARYANA           4554.0  1429.0   23.0  2903.0   273.0  5017.0
#        HIMACHAL PRADESH  1980.0   434.0    NaN  1129.0   140.0  1080.0
#        JAMMU & KASHMIR   1690.0   383.0    NaN   502.0   174.0   655.0
#        PUNJAB            4951.0  2085.0    NaN  3391.0   873.0  4932.0
# GT-2   BIHAR             7441.0  1479.0    NaN  3870.0  1059.0  7523.0
#        DELHI             4214.0  2039.0    7.0  4337.0   760.0  9195.0
#        JHARKHAND         4775.0  2378.0    NaN  2176.0  1094.0  6888.0
#        RAJASTHAN-1       3723.0  1179.0    NaN  1901.0   854.0  4274.0
#        RAJASTHAN-2       1301.0   260.0    NaN   360.0   344.0  1443.0
# GT-3   CENTRAL -UP-1     4343.0   622.0    NaN  1326.0  3532.0  4120.0
#        CENTRAL -UP-2     3052.0   499.0    NaN  1529.0  2502.0  2292.0
# ...

# %%
df_2.to_csv('test-2.csv')

# %% [markdown]
# # 6_Months

# %%
# All Codes

six_months=pd.concat([Nov_2021,Dec_2021,Jan_2022,Feb_2022,March_2022,Apr_2022])
Unique_Outlet=six_months.groupby(['REGION','STATE','PRODUCT NEW'])['OUTLET ID'].nunique()
Unique_Outlet.to_csv('six_months_Catogories_wise_total_unique_outlet.csv')
data_6month=pd.read_csv('six_months_Catogories_wise_total_unique_outlet.csv')
df_6=data_6month.set_index(['REGION','STATE','PRODUCT NEW'])['OUTLET ID'].unstack()
df_6=data_6month.pivot(index=['REGION','STATE'], columns='PRODUCT NEW', values='OUTLET ID')

# %%
df_6
# Out:
# PRODUCT NEW                   BL     GGP     GR    Hing     KWL       MM  \
# REGION STATE
# GT-1   CHANDIGARH          532.0   310.0   40.0   466.0    18.0    417.0
#        HARYANA            7400.0  4152.0   78.0  5322.0   682.0   7562.0
#        HIMACHAL PRADESH   2946.0  1379.0    NaN  2068.0   336.0   2344.0
#        JAMMU & KASHMIR    2614.0  1344.0    NaN  1042.0   335.0   1087.0
#        PUNJAB             8108.0  4897.0   60.0  6835.0  1940.0   8482.0
# GT-2   BIHAR             10992.0  3787.0   20.0  6902.0  2650.0  10603.0
#        DELHI              7235.0  5151.0   63.0  7937.0  1743.0  11901.0
#        JHARKHAND          6847.0  4985.0   58.0  4379.0  2181.0   8362.0
#        RAJASTHAN-1        5700.0  3328.0    NaN  3623.0  1751.0   6464.0
#        RAJASTHAN-2        2145.0   803.0    NaN   678.0   835.0   2449.0
# GT-3   CENTRAL -UP-1      7094.0  1807.0    NaN  2877.0  5572.0   6941.0
#        CENTRAL -UP-2      4880.0  1469.0    NaN  2921.0  3825.0   4077.0
# ...

# %%
df_6.to_csv('six_months_Catogories_wise_total_unique_outlet_count.csv')
