# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\Secondary\Apr_2022.csv',encoding = 'unicode_escape')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df1.head(2)
# Out:
#   REGION        STATE  OUTLET ID           OUTLET NAME       DATE  \
# 0   GT-4          NER    7032923           A.C.T store  01-Apr-22
# 1   GT-4  WEST BENGAL     372276  sipahi shaw and sons  01-Apr-22
#
#     Invoice_ID           Bill_No   SKU CODE          SKU CODE.1  \
# 0  5.473120e+24  N700159212203060        34   FGFFS1251100G-010
# 1  4.154130e+24  HF00043212205059      3233  FGFFS03211500G-002
#
#   OUTLET CLASSIFICATION  ... Size_GMS Qty_In_Kgs  Total_Qty Discount  \
# 0         GENERAL STORE  ...    100.0        0.1          1        0
# 1         GENERAL STORE  ...    500.0        6.0         12        0
#
#    Scheme_Discount  MRP Unitprice   Amount     Order_State       Sale_Type
# 0           0.0000   34   25.5000    25.50  Secondary Sale  Secondary Sale
# 1           7.2695  155   96.5805  1158.97  Secondary Sale  Secondary Sale
#
# [2 rows x 65 columns]

# %%
temp=df1.iloc[:,0:3]

# %%
temp.nunique()
# Out:
# REGION            7
# STATE            31
# OUTLET ID    143524
# dtype: int64

# %%
April_2022=df1.groupby(['REGION','STATE'])['OUTLET ID'].nunique()

# %%
April_2022
# Out:
# REGION  STATE
# GT-1    CHANDIGARH            505
#         HARYANA              7625
#         HIMACHAL PRADESH     2093
#         JAMMU & KASHMIR      2260
#         PUNJAB               8265
# GT-2    BIHAR               10730
#         DELHI               11573
#         JHARKHAND            7434
#         RAJASTHAN-1          5697
#         RAJASTHAN-2          1149
# GT-3    CENTRAL -UP-1        6918
#         CENTRAL -UP-2        4264
#         EASTERN UP          12542
#         UTTRAKHAND           7026
#         WEST-UP-1            9855
#         WEST-UP-2            5169
#         WEST-UP-3            4402
# GT-4    NER                  7390
#         ORISSA               2056
#         WEST BENGAL          9496
# GT-5    CHHATTISGARH         1155
#         MADHYA PRADESH-1     4798
#         MADHYA PRADESH-2     1904
# GT-6    GOA                  1232
#         GUJARAT              2559
#         MUMBAI               2713
#         ROM                  1618
# ...

# %%
outlel.to_csv('outlet_id1.csv')

# %%
April_2022.to_csv('April_2022.csv')

# %% [markdown]
# # Categories_wise

# %%
df1.head(2)
# Out:
#   REGION        STATE  OUTLET ID           OUTLET NAME       DATE  \
# 0   GT-4          NER    7032923           A.C.T store  01-Apr-22
# 1   GT-4  WEST BENGAL     372276  sipahi shaw and sons  01-Apr-22
#
#     Invoice_ID           Bill_No   SKU CODE          SKU CODE.1  \
# 0  5.473120e+24  N700159212203060        34   FGFFS1251100G-010
# 1  4.154130e+24  HF00043212205059      3233  FGFFS03211500G-002
#
#   OUTLET CLASSIFICATION  ... Size_GMS Qty_In_Kgs  Total_Qty Discount  \
# 0         GENERAL STORE  ...    100.0        0.1          1        0
# 1         GENERAL STORE  ...    500.0        6.0         12        0
#
#    Scheme_Discount  MRP Unitprice   Amount     Order_State       Sale_Type
# 0           0.0000   34   25.5000    25.50  Secondary Sale  Secondary Sale
# 1           7.2695  155   96.5805  1158.97  Secondary Sale  Secondary Sale
#
# [2 rows x 65 columns]

# %%
data=df1.iloc[:,0:15]

# %%
data.head(3)
# Out:
#   REGION        STATE  OUTLET ID           OUTLET NAME       DATE  \
# 0   GT-4          NER    7032923           A.C.T store  01-Apr-22
# 1   GT-4  WEST BENGAL     372276  sipahi shaw and sons  01-Apr-22
# 2   GT-4  WEST BENGAL     372276  sipahi shaw and sons  01-Apr-22
#
#     Invoice_ID           Bill_No   SKU CODE          SKU CODE.1  \
# 0  5.473120e+24  N700159212203060        34   FGFFS1251100G-010
# 1  4.154130e+24  HF00043212205059      3233  FGFFS03211500G-002
# 2  4.154130e+24  HF00043212205059      3395  FGFFS03211050G-002
#
#   OUTLET CLASSIFICATION OUTLET CATEGORY PRODUCT NEW   VAL IN LACS   \
# 0         GENERAL STORE               C          ST           0.00
# 1         GENERAL STORE               B         KWL           0.01
# 2         GENERAL STORE               B         KWL           0.01
#
#    VAL IN QNTL    Net Value
# 0         0.00          0.00
# 1         0.06          0.01
# 2         0.03          0.01

# %%
April_2022=df1.groupby(['REGION','STATE','PRODUCT NEW'])['OUTLET ID'].nunique()

# %%
unique_outlet=pd.DataFrame(April_2022)

# %%
unique_outlet
# Out:
#                                OUTLET ID
# REGION STATE      PRODUCT NEW
# GT-1   CHANDIGARH BL                 310
#                   GGP                163
#                   GR                  10
#                   Hing               240
#                   KWL                 11
# ...                                  ...
# GT-7   TAMILNADU  PRS                  4
#                   SP                 330
#                   ST                  68
#                   STP                178
#                   W                   19
#
# [348 rows x 1 columns]

# %%
unique_outlet.to_csv('testing.csv')

# %%
df=pd.read_csv('testing.csv')

# %%
df
# Out:
#     REGION       STATE PRODUCT NEW  OUTLET ID
# 0     GT-1  CHANDIGARH          BL        310
# 1     GT-1  CHANDIGARH         GGP        163
# 2     GT-1  CHANDIGARH          GR         10
# 3     GT-1  CHANDIGARH        Hing        240
# 4     GT-1  CHANDIGARH         KWL         11
# ..     ...         ...         ...        ...
# 343   GT-7   TAMILNADU         PRS          4
# 344   GT-7   TAMILNADU          SP        330
# 345   GT-7   TAMILNADU          ST         68
# 346   GT-7   TAMILNADU         STP        178
# 347   GT-7   TAMILNADU           W         19
#
# [348 rows x 4 columns]

# %%
df_1=df.set_index(['REGION','STATE','PRODUCT NEW'])['OUTLET ID'].unstack()
df_1=df.pivot(index=['REGION','STATE'], columns='PRODUCT NEW', values='OUTLET ID')

# %%
April_2022=df1.groupby(['REGION','STATE','PRODUCT NEW'])['OUTLET ID'].nunique()
unique_outlet=pd.DataFrame(April_2022)
unique_outlet.to_csv('testing.csv')
df=pd.read_csv('testing.csv')
df_1=df.set_index(['REGION','STATE','PRODUCT NEW'])['OUTLET ID'].unstack()
df_1=df.pivot(index=['REGION','STATE'], columns='PRODUCT NEW', values='OUTLET ID')

# %%
df_1
# Out:
# PRODUCT NEW                  BL     GGP     GR    Hing     KWL      MM  \
# REGION STATE
# GT-1   CHANDIGARH         310.0   163.0   10.0   240.0    11.0   243.0
#        HARYANA           3379.0  1189.0   30.0  1751.0   225.0  3898.0
#        HIMACHAL PRADESH  1457.0   506.0    NaN   648.0    86.0  1347.0
#        JAMMU & KASHMIR   1276.0   645.0    NaN   222.0   104.0   415.0
#        PUNJAB            3265.0  1567.0   50.0  1932.0   593.0  3636.0
# GT-2   BIHAR             5639.0  1289.0   18.0  2296.0   871.0  5451.0
#        DELHI             2694.0  1141.0   42.0  2338.0   498.0  6458.0
#        JHARKHAND         3507.0  1480.0   51.0  1153.0   672.0  4766.0
#        RAJASTHAN-1       2639.0  1044.0    NaN  1082.0   577.0  3571.0
#        RAJASTHAN-2        368.0   208.0    NaN    68.0   156.0   517.0
# GT-3   CENTRAL -UP-1     2674.0   226.0    NaN   456.0  1801.0  2896.0
#        CENTRAL -UP-2     1979.0   392.0    NaN   460.0  1330.0  1477.0
# ...

# %%
df_1.to_csv('Product_wise_unique_Outlet.csv')

# %%
# df_pivot=df_melt.pivot(index=['REGION','STATE'], columns='PRODUCT NEW',values=['OUTLET ID'])
# df_pivot

# %%
# df_melt=pd.melt(x, id_vars=[‘REGION’,’STATE’],value_vars=[‘MinDuration’,’MaxDuration’],var_name=’DurationType’,value_name=’Duration’)
# df_melt

# %%
print(df1.shape)
data1=df1.drop_duplicates('OUTLET ID')
print(data1.shape)
# Out:
# (830501, 65)
# (143524, 65)

# %%
a=data1.iloc[:,0:3]

# %%
a.to_csv('April-2022.csv')

# %%
Pivot_Outlet_id=pd.pivot_table(data1,values=['OUTLET ID'],index=['REGION','STATE'],aggfunc=())
Pivot_Outlet_id
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df2=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\Secondary\Dec-2021.csv',encoding = 'unicode_escape')
#df2  #dec-2021
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
print(df2.shape)
data2=df2.drop_duplicates('OUTLET ID')
print(data2.shape)
# Out:
# (841547, 65)
# (136274, 65)

# %%
April_2022=df1.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
dec_2021=df2.groupby(['REGION','STATE'])['OUTLET ID'].nunique()

# %%
dec_2021
# Out:
# REGION  STATE
# GT-1    CHANDIGARH            518
#         HARYANA              6973
#         HIMACHAL PRADESH     2418
#         JAMMU & KASHMIR      2399
#         PUNJAB               7444
# GT-2    BIHAR                9825
#         DELHI               11940
#         JHARKHAND            7228
#         RAJASTHAN-1          5292
#         RAJASTHAN-2          2073
# GT-3    CENTRAL -UP-1        6595
#         CENTRAL -UP-2        4286
#         EASTERN UP          10869
#         UTTRAKHAND           6778
#         WEST-UP-1           10153
#         WEST-UP-2            4607
#         WEST-UP-3            3757
# GT-4    NER                  7164
#         ORISSA               2262
#         WEST BENGAL          9057
# GT-5    CHHATTISGARH          756
#         MADHYA PRADESH-1     3832
#         MADHYA PRADESH-2     1710
# GT-6    GOA                  1218
#         GUJARAT              1780
#         MUMBAI               2223
#         ROM                  1108
# ...

# %%
dec_2021.to_csv('dec_2021.csv')

# %%
df3=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\secondary\Feb_2022.csv',encoding = 'unicode_escape')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (12,13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df3.head(2)
# Out:
#   REGION      STATE  OUTLET ID      OUTLET NAME       DATE   Invoice_ID   \
# 0   GT-2  JHARKHAND     215145  BABULAL AGARWAL  01-Feb-22  5.028190e+24
# 1   GT-2  JHARKHAND     215145  BABULAL AGARWAL  01-Feb-22  5.028190e+24
#
#            Bill_No   SKU CODE         SKU CODE.1 OUTLET CLASSIFICATION  ...  \
# 0  N800081212202886        26  FGFFS1241100G-010         GENERAL STORE  ...
# 1  N800081212202886        27  FGFFS1241200G-011         GENERAL STORE  ...
#
#   Size_GMS Qty_In_Kgs Total_Qty Discount Scheme_Discount MRP Unitprice  \
# 0    100.0        3.0        30        0          0.7650  34   24.7350
# 1    200.0        5.0        25        0          1.5075  67   48.7425
#
#     Amount     Order_State       Sale_Type
# 0   742.05  Secondary Sale  Secondary Sale
# 1  1218.56  Secondary Sale  Secondary Sale
#
# [2 rows x 65 columns]

# %%
April_2022=df1.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
dec_2021=df2.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
Feb_2022=df3.groupby(['REGION','STATE'])['OUTLET ID'].nunique()

# %%
Feb_2022
# Out:
# REGION  STATE
# GT-1    CHANDIGARH            522
#         HARYANA              7492
#         HIMACHAL PRADESH     2260
#         JAMMU & KASHMIR      2312
#         PUNJAB               8010
# GT-2    BIHAR               10474
#         DELHI               12215
#         JHARKHAND            7261
#         RAJASTHAN-1          5462
#         RAJASTHAN-2          2084
# GT-3    CENTRAL -UP-1        7205
#         CENTRAL -UP-2        4404
#         EASTERN UP          11983
#         UTTRAKHAND           7451
#         WEST-UP-1           10855
#         WEST-UP-2            5457
#         WEST-UP-3            3699
# GT-4    NER                  7375
#         ORISSA               2342
#         WEST BENGAL         10675
# GT-5    CHHATTISGARH         1251
#         MADHYA PRADESH-1     4520
#         MADHYA PRADESH-2     1758
# GT-6    GOA                  1238
#         GUJARAT              2185
#         MUMBAI               2689
#         ROM                  1899
# ...

# %%
Feb_2022.to_csv('Feb_2022.csv')

# %%
print(df3.shape)
data3=df3.drop_duplicates('OUTLET ID')
print(data3.shape)
# Out:
# (888677, 65)
# (147164, 65)

# %%
df4=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\secondary\Jan_2022.csv',encoding = 'unicode_escape')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (12,13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df4.head(2)
# Out:
#   REGION       STATE  OUTLET ID                     OUTLET NAME       DATE  \
# 0   GT-2       BIHAR     370096               MAA GENERAL STORE  01-Jan-22
# 1   GT-3  EASTERN UP     192707  Vishal kirana store [Hallaur ]  01-Jan-22
#
#     Invoice_ID           Bill_No   SKU CODE         SKU CODE.1  \
# 0  4.304520e+24               493       138  FGFFS1497016G-011
# 1  8.842150e+17  I100159212200471        35  FGFFS1251200G-011
#
#   OUTLET CLASSIFICATION  ... Size_GMS Qty_In_Kgs Total_Qty Discount  \
# 0         GENERAL STORE  ...     16.0       0.32        20        0
# 1         GENERAL STORE  ...    200.0      30.40       152        0
#
#   Scheme_Discount MRP Unitprice  Amount     Order_State       Sale_Type
# 0            0.76  10      7.24   144.8  Secondary Sale  Secondary Sale
# 1            0.00  67     50.25  7638.0  Secondary Sale  Secondary Sale
#
# [2 rows x 65 columns]

# %%
April_2022=df1.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
dec_2021=df2.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
Feb_2022=df3.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
Jan_2022=df4.groupby(['REGION','STATE'])['OUTLET ID'].nunique()

# %%
Jan_2022
# Out:
# REGION  STATE
# GT-1    CHANDIGARH            500
#         HARYANA              7244
#         HIMACHAL PRADESH     2226
#         JAMMU & KASHMIR      2022
#         PUNJAB               7760
# GT-2    BIHAR               10058
#         DELHI               12084
#         JHARKHAND            7135
#         RAJASTHAN-1          5377
#         RAJASTHAN-2          2119
# GT-3    CENTRAL -UP-1        7470
#         CENTRAL -UP-2        4353
#         EASTERN UP          11232
#         UTTRAKHAND           7122
#         WEST-UP-1           10225
#         WEST-UP-2            5249
#         WEST-UP-3            3707
# GT-4    NER                  7138
#         ORISSA               2087
#         WEST BENGAL          9376
# GT-5    CHHATTISGARH         1012
#         MADHYA PRADESH-1     3764
#         MADHYA PRADESH-2     1814
# GT-6    GOA                  1281
#         GUJARAT              2016
#         MUMBAI               2388
#         ROM                  1605
# ...

# %%
Jan_2022.to_csv('Jan_2022.csv')

# %%
print(df4.shape)
data4=df4.drop_duplicates('OUTLET ID')
print(data4.shape)
# Out:
# (805601, 65)
# (140227, 65)

# %%
df5=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\secondary\March_2022.csv',encoding = 'unicode_escape')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (12,13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df5.head(2)
# Out:
#   REGION      STATE  OUTLET ID       OUTLET NAME       DATE   Invoice_ID   \
# 0   GT-3  WEST-UP-3     632725  New Balaji store  01-Mar-22  9.596410e+24
# 1   GT-3  WEST-UP-3     632725  New Balaji store  01-Mar-22  9.596410e+24
#
#            Bill_No   SKU CODE         SKU CODE.1 OUTLET CLASSIFICATION  ...  \
# 0  NB00010212201916        77  FGFFS159N025G-015         GENERAL STORE  ...
# 1  NB00010212201916     12450  FGFFS1297050G-002         GENERAL STORE  ...
#
#   Size_GMS Qty_In_Kgs Total_Qty Discount Scheme_Discount MRP Unitprice Amount  \
# 0     25.0       0.50        20        0            1.35  60     43.65  873.0
# 1     50.0       0.15         3        0            0.00  40     30.00   90.0
#
#       Order_State       Sale_Type
# 0  Secondary Sale  Secondary Sale
# 1  Secondary Sale  Secondary Sale
#
# [2 rows x 65 columns]

# %%
April_2022=df1.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
dec_2021=df2.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
Feb_2022=df3.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
Jan_2022=df4.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
March_2022=df5.groupby(['REGION','STATE'])['OUTLET ID'].nunique()

# %%
March_2022
# Out:
# REGION  STATE
# GT-1    CHANDIGARH            534
#         HARYANA              7575
#         HIMACHAL PRADESH     2290
#         JAMMU & KASHMIR      2388
#         PUNJAB               8307
# GT-2    BIHAR               10438
#         DELHI               12490
#         JHARKHAND            7373
#         RAJASTHAN-1          5557
#         RAJASTHAN-2          1652
# GT-3    CENTRAL -UP-1        7094
#         CENTRAL -UP-2        4045
#         EASTERN UP          12288
#         UTTRAKHAND           7308
#         WEST-UP-1           10855
#         WEST-UP-2            5233
#         WEST-UP-3            4301
# GT-4    NER                  7641
#         ORISSA               2143
#         WEST BENGAL         10610
# GT-5    CHHATTISGARH         1166
#         MADHYA PRADESH-1     4699
#         MADHYA PRADESH-2     1588
# GT-6    GOA                  1281
#         GUJARAT              2390
#         MUMBAI               2988
#         ROM                  1576
# ...

# %%
March_2022.to_csv('March_2022.csv')

# %%
print(df5.shape)
data5=df5.drop_duplicates('OUTLET ID')
print(data5.shape)
# Out:
# (985091, 65)
# (147606, 65)

# %%
df6=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\secondary\Nov_2021.csv',encoding = 'unicode_escape')

# %%
df6.head(2)
# Out:
#   REGION        STATE  OUTLET ID  OUTLET NAME   DATE   Invoice_ID  Bill_No   \
# 0   GT-2  RAJASTHAN-2     376118  Malik Store  44501  1.293520e+24     1029
# 1   GT-2  RAJASTHAN-2     376118  Malik Store  44501  1.293520e+24     1029
#
#    SKU CODE         SKU CODE.1 OUTLET CLASSIFICATION  ... Size_GMS Qty_In_Kgs  \
# 0       110  FGFFS1427016G-011         GENERAL STORE  ...     16.0       0.16
# 1       130  FGFFS1A47016G-007         GENERAL STORE  ...     16.0       0.16
#
#    Total_Qty  Discount  Scheme_Discount MRP Unitprice Amount     Order_State  \
# 0         10         0             0.48  10      7.52   75.2  Secondary Sale
# 1         10         0             0.48  10      7.52   75.2  Secondary Sale
#
#         Sale_Type
# 0  Secondary Sale
# 1  Secondary Sale
#
# [2 rows x 65 columns]

# %%
Nov_2021=df6.groupby(['REGION','STATE'])['OUTLET ID'].nunique()

# %%
Nov_2021
# Out:
# REGION  STATE
# GT-1    CHANDIGARH            510
#         HARYANA              6334
#         HIMACHAL PRADESH     1958
#         JAMMU & KASHMIR      2206
#         PUNJAB               6735
# GT-2    BIHAR                9183
#         DELHI               10768
#         JHARKHAND            6702
#         RAJASTHAN-1          4608
#         RAJASTHAN-2          1730
# GT-3    CENTRAL -UP-1        6913
#         CENTRAL -UP-2        3925
#         EASTERN UP          10240
#         UTTRAKHAND           6501
#         WEST-UP-1           10336
#         WEST-UP-2            4641
#         WEST-UP-3            4108
# GT-4    NER                  6616
#         ORISSA               2048
#         WEST BENGAL          9239
# GT-5    CHHATTISGARH          638
#         MADHYA PRADESH-1     3610
#         MADHYA PRADESH-2     1024
# GT-6    GOA                  1130
#         GUJARAT              2205
#         MUMBAI               2140
#         ROM                  1210
# ...

# %%
Nov_2021.to_csv('Nov_2021.csv')

# %%
print(df6.shape)
data6=df6.drop_duplicates('OUTLET ID')
print(data6.shape)
# Out:
# (779895, 65)
# (128840, 65)

# %%
x=pd.DataFrame(Nov_2021)

# %%
import pandas as pd
df1=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\Secondary\Apr_2022.csv',encoding = 'unicode_escape')
df2=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\Secondary\Dec-2021.csv',encoding = 'unicode_escape')
df3=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\secondary\Feb_2022.csv',encoding = 'unicode_escape')
df4=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\secondary\Jan_2022.csv',encoding = 'unicode_escape')
df5=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\secondary\March_2022.csv',encoding = 'unicode_escape')
df6=pd.read_csv(r'C:\Users\deepak.kumar13\Desktop\secondary\Nov_2021.csv',encoding = 'unicode_escape')
# April_2022=df1.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
# dec_2021=df2.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
# Feb_2022=df3.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
# Jan_2022=df4.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
# March_2022=df5.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
# Nov_2021=df6.groupby(['REGION','STATE'])['OUTLET ID'].nunique()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (12,13,14) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_list=[df1,df2,df3,df4,df5,df6]
df_list=[df.iloc[:,0:3].groupby(['REGION','STATE'])['OUTLET ID'].nunique() for df in df_list]

# %%
df_list
# Out:
# [REGION  STATE
#  GT-1    CHANDIGARH            505
#          HARYANA              7625
#          HIMACHAL PRADESH     2093
#          JAMMU & KASHMIR      2260
#          PUNJAB               8265
#  GT-2    BIHAR               10730
#          DELHI               11573
#          JHARKHAND            7434
#          RAJASTHAN-1          5697
#          RAJASTHAN-2          1149
#  GT-3    CENTRAL -UP-1        6918
#          CENTRAL -UP-2        4264
#          EASTERN UP          12542
#          UTTRAKHAND           7026
#          WEST-UP-1            9855
#          WEST-UP-2            5169
#          WEST-UP-3            4402
#  GT-4    NER                  7390
#          ORISSA               2056
#          WEST BENGAL          9496
#  GT-5    CHHATTISGARH         1155
#          MADHYA PRADESH-1     4798
#          MADHYA PRADESH-2     1904
#  GT-6    GOA                  1232
#          GUJARAT              2559
#          MUMBAI               2713
# ...

# %%
df_list=pd.concat([df1,df2,df3,df4,df5,df6],axis=1)

# %%
df_list
# Out:
#        REGION          STATE  OUTLET ID           OUTLET NAME       DATE  \
# 0        GT-4            NER  7032923.0           A.C.T store  01-Apr-22
# 1        GT-4    WEST BENGAL   372276.0  sipahi shaw and sons  01-Apr-22
# 2        GT-4    WEST BENGAL   372276.0  sipahi shaw and sons  01-Apr-22
# 3        GT-3  CENTRAL -UP-2   607748.0          Vinit Kirana  01-Apr-22
# 4        GT-3  CENTRAL -UP-2   607748.0          Vinit Kirana  01-Apr-22
# ...       ...            ...        ...                   ...        ...
# 985086    NaN            NaN        NaN                   NaN        NaN
# 985087    NaN            NaN        NaN                   NaN        NaN
# 985088    NaN            NaN        NaN                   NaN        NaN
# 985089    NaN            NaN        NaN                   NaN        NaN
# 985090    NaN            NaN        NaN                   NaN        NaN
#
#          Invoice_ID           Bill_No   SKU CODE          SKU CODE.1  \
# ...

# %%
df_list.columns
# Out:
# Index(['REGION', 'STATE', 'OUTLET ID', 'OUTLET NAME', 'DATE', 'Invoice_ID ',
#        'Bill_No ', 'SKU CODE', 'SKU CODE.1', 'OUTLET CLASSIFICATION',
#        ...
#        'Size_GMS', 'Qty_In_Kgs', 'Total_Qty', 'Discount', 'Scheme_Discount',
#        'MRP', 'Unitprice', 'Amount', 'Order_State', 'Sale_Type'],
#       dtype='object', length=390)

# %%
df1.columns
# Out:
# Index(['REGION', 'STATE', 'OUTLET ID', 'OUTLET NAME', 'DATE', 'Invoice_ID ',
#        'Bill_No ', 'SKU CODE', 'SKU CODE.1', 'OUTLET CLASSIFICATION',
#        'OUTLET CATEGORY', 'PRODUCT NEW', ' VAL IN LACS ', ' VAL IN QNTL ',
#        ' Net Value ', 'Zone', 'State', 'Subzone', 'City', 'Role',
#        'Reporting_Manager', 'SS_Name', 'SS_Code', 'Distributor_Code',
#        'Distributor_Name', 'User_Id', 'Bizom_User_ID', 'Employee_Name',
#        'User_Status', 'Designation', 'Invoice_ID', 'Bill_No', 'Order_ID',
#        'Order_Date', 'Order_Time', 'Pjp_Outlet', 'Reason', 'Sale_Date',
#        'Sale_Time', 'Outlet_Id', 'Outlet_Created', 'Outlet_Name', 'Beat_Id',
#        'Beat_Name', 'Type', 'Outlet_Category', 'Latitude', 'Longitude',
#        'Mobile_Number', 'SKU_ID', 'Sku_Placed', 'Category', 'Sku_Brand',
#        'Subcategory', 'SKU_Code', 'Size_GMS', 'Qty_In_Kgs', 'Total_Qty',
#        'Discount', 'Scheme_Discount', 'MRP', 'Unitprice', 'Amount',
# ...

# %%
d=df_list[['REGION','STATE','OUTLET ID']]

# %%
d
# Out:
#        REGION REGION REGION REGION REGION REGION          STATE  \
# 0        GT-4   GT-3   GT-2   GT-2   GT-3   GT-2            NER
# 1        GT-4   GT-3   GT-2   GT-3   GT-3   GT-2    WEST BENGAL
# 2        GT-4   GT-3   GT-2   GT-4   GT-2   GT-2    WEST BENGAL
# 3        GT-3   GT-3   GT-5   GT-4   GT-2   GT-2  CENTRAL -UP-2
# 4        GT-3   GT-3   GT-2   GT-4   GT-2   GT-2  CENTRAL -UP-2
# ...       ...    ...    ...    ...    ...    ...            ...
# 985086    NaN    NaN    NaN    NaN   GT-4    NaN            NaN
# 985087    NaN    NaN    NaN    NaN   GT-4    NaN            NaN
# 985088    NaN    NaN    NaN    NaN   GT-4    NaN            NaN
# 985089    NaN    NaN    NaN    NaN   GT-4    NaN            NaN
# 985090    NaN    NaN    NaN    NaN   GT-4    NaN            NaN
#
#                 STATE         STATE       STATE        STATE        STATE  \
# 0           WEST-UP-2     JHARKHAND       BIHAR    WEST-UP-3  RAJASTHAN-2
# ...

# %%
data=pd.DataFrame()

# %%
data['REGION']=d.iloc[:,4:5]
data['STATE']=d.iloc[:,10:11]
data['OUTLET_ID']=d.iloc[:,16:17]

# %%
data1=pd.DataFrame()
data1['outlet_1']=d.iloc[:,12:13]
data1['outlet_2']=d.iloc[:,13:14]
data1['outlet_3']=d.iloc[:,14:15]
data1['outlet_4']=d.iloc[:,15:16]
data1['outlet_5']=d.iloc[:,17:18]

# %%
data2
# Out:
#        REGION        STATE  OUTLET_ID   outlet_1  outlet_2  outlet_3  \
# 0        GT-3    WEST-UP-3     632725  7032923.0  416258.0  215145.0
# 1        GT-3    WEST-UP-3     632725   372276.0  544995.0  215145.0
# 2        GT-2  RAJASTHAN-2     410904   372276.0  544995.0  215145.0
# 3        GT-2  RAJASTHAN-2    7020202   607748.0  173559.0  409210.0
# 4        GT-2  RAJASTHAN-2     631271   607748.0  499850.0  215291.0
# ...       ...          ...        ...        ...       ...       ...
# 985086   GT-4  WEST BENGAL     232473        NaN       NaN       NaN
# 985087   GT-4  WEST BENGAL     232473        NaN       NaN       NaN
# 985088   GT-4          NER    7034710        NaN       NaN       NaN
# 985089   GT-4          NER     536031        NaN       NaN       NaN
# 985090   GT-4  WEST BENGAL     465250        NaN       NaN       NaN
#
#         outlet_4  outlet_5
# 0       370096.0  376118.0
# 1       192707.0  376118.0
# 2       507043.0  376118.0
# ...

# %%
data1
# Out:
#          outlet_1  outlet_2  outlet_3  outlet_4  outlet_5
# 0       7032923.0  416258.0  215145.0  370096.0  376118.0
# 1        372276.0  544995.0  215145.0  192707.0  376118.0
# 2        372276.0  544995.0  215145.0  507043.0  376118.0
# 3        607748.0  173559.0  409210.0  507043.0  638329.0
# 4        607748.0  499850.0  215291.0  507043.0  638329.0
# ...           ...       ...       ...       ...       ...
# 985086        NaN       NaN       NaN       NaN       NaN
# 985087        NaN       NaN       NaN       NaN       NaN
# 985088        NaN       NaN       NaN       NaN       NaN
# 985089        NaN       NaN       NaN       NaN       NaN
# 985090        NaN       NaN       NaN       NaN       NaN
#
# [985091 rows x 5 columns]

# %%
data
# Out:
#        REGION        STATE  OUTLET_ID
# 0        GT-3    WEST-UP-3     632725
# 1        GT-3    WEST-UP-3     632725
# 2        GT-2  RAJASTHAN-2     410904
# 3        GT-2  RAJASTHAN-2    7020202
# 4        GT-2  RAJASTHAN-2     631271
# ...       ...          ...        ...
# 985086   GT-4  WEST BENGAL     232473
# 985087   GT-4  WEST BENGAL     232473
# 985088   GT-4          NER    7034710
# 985089   GT-4          NER     536031
# 985090   GT-4  WEST BENGAL     465250
#
# [985091 rows x 3 columns]

# %%
data2=pd.concat([data,data1],axis=1)

# %%
data2
# Out:
#        REGION        STATE  OUTLET_ID   outlet_1  outlet_2  outlet_3  \
# 0        GT-3    WEST-UP-3     632725  7032923.0  416258.0  215145.0
# 1        GT-3    WEST-UP-3     632725   372276.0  544995.0  215145.0
# 2        GT-2  RAJASTHAN-2     410904   372276.0  544995.0  215145.0
# 3        GT-2  RAJASTHAN-2    7020202   607748.0  173559.0  409210.0
# 4        GT-2  RAJASTHAN-2     631271   607748.0  499850.0  215291.0
# ...       ...          ...        ...        ...       ...       ...
# 985086   GT-4  WEST BENGAL     232473        NaN       NaN       NaN
# 985087   GT-4  WEST BENGAL     232473        NaN       NaN       NaN
# 985088   GT-4          NER    7034710        NaN       NaN       NaN
# 985089   GT-4          NER     536031        NaN       NaN       NaN
# 985090   GT-4  WEST BENGAL     465250        NaN       NaN       NaN
#
#         outlet_4  outlet_5
# 0       370096.0  376118.0
# 1       192707.0  376118.0
# 2       507043.0  376118.0
# ...

# %%
Unique_Outlet=data2.groupby(['REGION','STATE'])[['OUTLET_ID','outlet_1','outlet_2','outlet_3','outlet_5']].nunique()

# %%
Unique_Outlet
# Out:
#                          OUTLET_ID  outlet_1  outlet_2  outlet_3  outlet_5
# REGION STATE
# GT-1   CHANDIGARH              534      2360      2245      2206      2100
#        HARYANA                7575     16848     16486     16409     16478
#        HIMACHAL PRADESH       2290      6725      6840      6569      6413
#        JAMMU & KASHMIR        2388      4723      4348      4468      4351
#        PUNJAB                 8307     14817     14604     14385     14106
# GT-2   BIHAR                 10438     24767     23737     24228     23490
#        DELHI                 12490     25146     24370     24782     23821
#        JHARKHAND              7373     18162     17728     18009     17238
#        RAJASTHAN-1            5557      9776      9620      9445      9028
#        RAJASTHAN-2            1652      2151      1944      1906      1922
# GT-3   CENTRAL -UP-1          7094      9849      9318      9722      9488
# ...

# %%
All_Outlel_unique_id
# Out:
#    REGION             STATE  OUTLET_ID_Nov_2021  OUTLET_ID_dec_2021  \
# 0    GT-1        CHANDIGARH                 510                 518
# 1    GT-1           HARYANA                6334                6973
# 2    GT-1  HIMACHAL PRADESH                1958                2418
# 3    GT-1   JAMMU & KASHMIR                2206                2399
# 4    GT-1            PUNJAB                6735                7444
# 5    GT-2             BIHAR                9183                9825
# 6    GT-2             DELHI               10768               11940
# 7    GT-2         JHARKHAND                6702                7228
# 8    GT-2       RAJASTHAN-1                4608                5292
# 9    GT-2       RAJASTHAN-2                1730                2073
# 10   GT-3     CENTRAL -UP-1                6913                6595
# 11   GT-3     CENTRAL -UP-2                3925                4286
# 12   GT-3        EASTERN UP               10240               10869
# ...

# %%
pd.DataFrame(df_list)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals\construction.py:540: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   values = np.array([convert(v) for v in values])
#                                                    0
# 0         REGION          STATE  OUTLET ID       ...
# 1         REGION          STATE  OUTLET ID       ...
# 2         REGION          STATE  OUTLET ID       ...
# 3         REGION         STATE  OUTLET ID        ...
# 4         REGION        STATE  OUTLET ID         ...
# 5         REGION          STATE  OUTLET ID       ...

# %%
df_list[0].head(2)
# Out:
#   REGION        STATE  OUTLET ID           OUTLET NAME       DATE  \
# 0   GT-4          NER    7032923           A.C.T store  01-Apr-22
# 1   GT-4  WEST BENGAL     372276  sipahi shaw and sons  01-Apr-22
#
#     Invoice_ID           Bill_No   SKU CODE          SKU CODE.1  \
# 0  5.473120e+24  N700159212203060        34   FGFFS1251100G-010
# 1  4.154130e+24  HF00043212205059      3233  FGFFS03211500G-002
#
#   OUTLET CLASSIFICATION  ... Size_GMS Qty_In_Kgs  Total_Qty Discount  \
# 0         GENERAL STORE  ...    100.0        0.1          1        0
# 1         GENERAL STORE  ...    500.0        6.0         12        0
#
#    Scheme_Discount  MRP Unitprice   Amount     Order_State       Sale_Type
# 0           0.0000   34   25.5000    25.50  Secondary Sale  Secondary Sale
# 1           7.2695  155   96.5805  1158.97  Secondary Sale  Secondary Sale
#
# [2 rows x 65 columns]

# %%
col_list=['REGION','STATE','OUTLET ID']
df_list=[df1,df2,df3,df4,df5,df6]

def dead(df):
    for df1 in df_list:
        if df1.columns in col_list:
            if df1.columns==col_list: 
                return df1.columns

df1.apply(dead)

# %%
col_list=['age1','age2']
df_list=[df,df2]

def dead(df):
    for df in df_list:
        if df.columns in col_list:
            if df.columns >=100:
                return 'dead'
            else:
                return df.columns

df.apply(dead)

# %%
# data=pd.merge(April_2022,dec_2021,Feb_2022,Jan_2022,March_2022,Nov_2021,on='REGION',how='full outer')

# %%
OUTLET_ID_Nov_2021

# %%
All_Outlel_unique_id=pd.read_excel(r'C:\Users\deepak.kumar13\Desktop\Python\Secondary_FF\Unique_Outlet_Data.xlsx')
All_Outlel_unique_id
# Out:
#    REGION             STATE  OUTLET_ID_Nov_2021  OUTLET_ID_dec_2021  \
# 0    GT-1        CHANDIGARH                 510                 518
# 1    GT-1           HARYANA                6334                6973
# 2    GT-1  HIMACHAL PRADESH                1958                2418
# 3    GT-1   JAMMU & KASHMIR                2206                2399
# 4    GT-1            PUNJAB                6735                7444
# 5    GT-2             BIHAR                9183                9825
# 6    GT-2             DELHI               10768               11940
# 7    GT-2         JHARKHAND                6702                7228
# 8    GT-2       RAJASTHAN-1                4608                5292
# 9    GT-2       RAJASTHAN-2                1730                2073
# 10   GT-3     CENTRAL -UP-1                6913                6595
# 11   GT-3     CENTRAL -UP-2                3925                4286
# 12   GT-3        EASTERN UP               10240               10869
# ...

# %%
All_Outlel_unique_id['OUTLET_ID_Nov_2021'].sum()
# Out:
# 257680

# %%
257680-128840
# Out:
# 128840

# %%
data=pd.concat([df1,df2,df3,df4,df5,df6])

# %%
data.shape
# Out:
# (5131312, 68)

# %%
data.head()
# Out:
#   REGION          STATE  OUTLET ID           OUTLET NAME       DATE  \
# 0   GT-4            NER    7032923           A.C.T store  01-Apr-22
# 1   GT-4    WEST BENGAL     372276  sipahi shaw and sons  01-Apr-22
# 2   GT-4    WEST BENGAL     372276  sipahi shaw and sons  01-Apr-22
# 3   GT-3  CENTRAL -UP-2     607748          Vinit Kirana  01-Apr-22
# 4   GT-3  CENTRAL -UP-2     607748          Vinit Kirana  01-Apr-22
#
#     Invoice_ID           Bill_No   SKU CODE          SKU CODE.1  \
# 0  5.473120e+24  N700159212203060        34   FGFFS1251100G-010
# 1  4.154130e+24  HF00043212205059      3233  FGFFS03211500G-002
# 2  4.154130e+24  HF00043212205059      3395  FGFFS03211050G-002
# 3  7.092500e+24  N400179212200861        13   FGFFS1211050G-009
# 4  7.092500e+24  N400179212200861        34   FGFFS1251100G-010
#
#   OUTLET CLASSIFICATION  ... Discount Scheme_Discount  MRP Unitprice   Amount  \
# 0         GENERAL STORE  ...        0          0.0000   34   25.5000    25.50
# ...

# %%
data.columns
# Out:
# Index(['REGION', 'STATE', 'OUTLET ID', 'OUTLET NAME', 'DATE', 'Invoice_ID ',
#        'Bill_No ', 'SKU CODE', 'SKU CODE.1', 'OUTLET CLASSIFICATION',
#        'OUTLET CATEGORY', 'PRODUCT NEW', ' VAL IN LACS ', ' VAL IN QNTL ',
#        ' Net Value ', 'Zone', 'State', 'Subzone', 'City', 'Role',
#        'Reporting_Manager', 'SS_Name', 'SS_Code', 'Distributor_Code',
#        'Distributor_Name', 'User_Id', 'Bizom_User_ID', 'Employee_Name',
#        'User_Status', 'Designation', 'Invoice_ID', 'Bill_No', 'Order_ID',
#        'Order_Date', 'Order_Time', 'Pjp_Outlet', 'Reason', 'Sale_Date',
#        'Sale_Time', 'Outlet_Id', 'Outlet_Created', 'Outlet_Name', 'Beat_Id',
#        'Beat_Name', 'Type', 'Outlet_Category', 'Latitude', 'Longitude',
#        'Mobile_Number', 'SKU_ID', 'Sku_Placed', 'Category', 'Sku_Brand',
#        'Subcategory', 'SKU_Code', 'Size_GMS', 'Qty_In_Kgs', 'Total_Qty',
#        'Discount', 'Scheme_Discount', 'MRP', 'Unitprice', 'Amount',
# ...

# %%
data2=df1.drop_duplicates('OUTLET ID')

# %%
data2.shape
# Out:
# (143524, 65)

# %%
data3=data2[['REGION','STATE','DATE','OUTLET ID']]

# %%
# folder_path = r'C:\Users\deepak.kumar13\Desktop\Secondary'
# file_list = glob.glob(folder_path + "/*.csv")
# main_dataframe = pd.DataFrame(pd.read_csv(file_list[0]))
# for i in range(1,len(file_list)):
#     data = pd.read_csv(file_list[i])
#     df = pd.DataFrame(data)
#     main_dataframe = pd.concat([main_dataframe,df])
# print(main_dataframe)

# %%
df3.head()
# Out:
#   REGION         STATE  OUTLET ID      OUTLET NAME       DATE   Invoice_ID   \
# 0   GT-2     JHARKHAND     215145  BABULAL AGARWAL  01-Feb-22  5.028190e+24
# 1   GT-2     JHARKHAND     215145  BABULAL AGARWAL  01-Feb-22  5.028190e+24
# 2   GT-2     JHARKHAND     215145  BABULAL AGARWAL  01-Feb-22  5.028190e+24
# 3   GT-5  CHHATTISGARH     409210     Om provision  01-Feb-22  1.556550e+24
# 4   GT-2     JHARKHAND     215291     PATHAK STORE  01-Feb-22  6.621190e+24
#
#            Bill_No   SKU CODE         SKU CODE.1 OUTLET CLASSIFICATION  ...  \
# 0  N800081212202886        26  FGFFS1241100G-010         GENERAL STORE  ...
# 1  N800081212202886        27  FGFFS1241200G-011         GENERAL STORE  ...
# 2  N800081212202886        28  FGFFS1241500G-009         GENERAL STORE  ...
# 3               794     12458  FGFFS1AE1020G-002         GENERAL STORE  ...
# 4  N800081212202887        26  FGFFS1241100G-010         GENERAL STORE  ...
#
# ...

# %%
new_df3
# Out:
# REGION  STATE
# GT-1    CHANDIGARH          [253024, 7024824, 252697, 252691, 390860, 5409...
#         HARYANA             [521170, 107394, 107332, 107750, 107436, 39193...
#         HIMACHAL PRADESH    [260925, 260954, 260955, 260956, 343480, 36243...
#         JAMMU & KASHMIR     [256897, 568448, 256905, 256899, 256898, 25689...
#         PUNJAB              [237440, 444562, 237430, 237435, 237431, 23743...
# GT-2    BIHAR               [633358, 577935, 207198, 579846, 207327, 46764...
#         DELHI               [13300, 13314, 13410, 67576, 67579, 67589, 559...
#         JHARKHAND           [215145, 215291, 630363, 215376, 215135, 21530...
#         RAJASTHAN-1         [364152, 374625, 493303, 371183, 533043, 36542...
#         RAJASTHAN-2         [619046, 554179, 345273, 304268, 533058, 45658...
# GT-3    CENTRAL -UP-1       [167566, 168905, 170800, 168167, 168813, 56571...
#         CENTRAL -UP-2       [171004, 165075, 165099, 167325, 168448, 16887...
# ...
